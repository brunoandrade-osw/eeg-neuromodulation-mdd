# %%
# 2 - ANÁLISE EXPLORATÓRIA

import os
import mne
import pandas as pd
import numpy as np

proc_dir = "/workspaces/eeg-neuromodulation-mdd/data/processed"
arquivos_proc = [f for f in os.listdir(proc_dir) if f.endswith('.fif')]

# Dicionário de bandas para o TDM
bandas = {'Delta': (0.5, 4), 'Theta': (4, 8), 'Alpha': (8, 13), 'Beta': (13, 30)}

resultados = []

for arq in arquivos_proc:
    raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
    
    # Cálculo da PSD (Welch)
    psd = raw.compute_psd(method='welch', fmin=0.5, fmax=45)
    psd_data, freqs = psd.get_data(return_freqs=True)
    
    # Extrair potência média de cada banda
    dados_paciente = {'paciente': arq}
    for nome, (fmin, fmax) in bandas.items():
        # Filtro de frequências
        mask = (freqs >= fmin) & (freqs <= fmax)
        potencia = np.mean(psd_data[:, mask], axis=1)
        dados_paciente[nome] = np.mean(potencia) # Média de todos os canais
        
    resultados.append(dados_paciente)

# Criar DataFrame final para análise
df_features = pd.DataFrame(resultados)
print(df_features.head())
# Out:
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.07.30-10.10.28]_cleaned.fif...
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# /tmp/ipykernel_63164/3876065029.py:17: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.07.30-10.10.28]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.09.30-15.03.51]_cleaned.fif...
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# /tmp/ipykernel_63164/3876065029.py:17: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.09.30-15.03.51]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.21-11.46.36]_cleaned.fif...
# /tmp/ipykernel_63164/3876065029.py:17: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.21-11.46.36]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.08.12-10.01.51]_cleaned.fif...
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# /tmp/ipykernel_63164/3876065029.py:17: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.08.12-10.01.51]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.20-09.47.01]_cleaned.fif...
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# /tmp/ipykernel_63164/3876065029.py:17: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.20-09.47.01]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.23-15.12.30]_cleaned.fif...
# /tmp/ipykernel_63164/3876065029.py:17: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.23-15.12.30]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# Effective window size : 4.000 (s)
#                                    paciente         Delta         Theta  \
# 0  record-[2025.07.30-10.10.28]_cleaned.fif  5.801496e-12  3.528656e-12
# 1  record-[2025.09.30-15.03.51]_cleaned.fif  4.672959e-12  2.467312e-12
# 2  record-[2025.10.21-11.46.36]_cleaned.fif  3.088031e-12  1.431189e-12
# 3  record-[2025.08.12-10.01.51]_cleaned.fif  2.012935e-12  1.720494e-12
# 4  record-[2025.10.20-09.47.01]_cleaned.fif  3.483710e-12  1.897495e-12
#
#           Alpha          Beta
# 0  2.099337e-11  1.110163e-12
# 1  2.776876e-12  5.757394e-13
# 2  1.225405e-12  7.368581e-13
# 3  2.605228e-12  4.897322e-13
# 4  8.549964e-12  6.518970e-13

# %%
# Verificar o que tem no processamento
print("Arquivos processados na tabela:")
print(df_features['paciente'].tolist())

# Verificar o que tem na planilha
print("\nArquivos listados na planilha:")
print(df_meta['nome_arquivo'].tolist())
# Out:
# Arquivos processados na tabela:
# ['record-[2025.07.30-10.10.28]_cleaned.fif', 'record-[2025.09.30-15.03.51]_cleaned.fif', 'record-[2025.10.21-11.46.36]_cleaned.fif', 'record-[2025.08.12-10.01.51]_cleaned.fif', 'record-[2025.10.20-09.47.01]_cleaned.fif', 'record-[2025.10.23-15.12.30]_cleaned.fif']
#
# Arquivos listados na planilha:
# ['record-[2025.07.30-10.10.28].csv', 'record-[2025.08.12-10.01.51].csv', 'record-[2025.09.30-15.03.51].csv', 'record-[2025.10.20-09.47.01].csv', 'record-[2025.10.21-11.46.36].csv', 'record-[2025.10.23-15.12.30].csv']

# %%
# Garantir que a coluna Alpha_Relativo existe
# Somar as potências das bandas para garantir o cálculo
df_features['Soma_Total'] = df_features['Delta'] + df_features['Theta'] + df_features['Alpha'] + df_features['Beta']
df_features['Alpha_Relativo'] = df_features['Alpha'] / df_features['Soma_Total']

# 2. Criar a chave de ligação (paciente_base)
df_features['paciente_base'] = df_features['paciente'].str.replace('_cleaned.fif', '.csv')

# 3. Fazer o merge
df_final = pd.merge(df_features, df_meta, left_on='paciente_base', right_on='nome_arquivo')

# 4. Verificação de segurança: imprimir todas as colunas disponíveis
print("Colunas presentes no df_final:")
print(df_final.columns.tolist())

# 5. Imprimir o resultado
if 'Alpha_Relativo' in df_final.columns:
    print("\nSucesso! Exibindo dados:")
    print(df_final[['paciente', 'grupo', 'Alpha_Relativo']])
else:
    print("\nERRO: Alpha_Relativo ainda não foi encontrada nas colunas!")
# Out:
# Colunas presentes no df_final:
# ['paciente', 'Delta', 'Theta', 'Alpha', 'Beta', 'paciente_base', 'Soma_Total', 'Alpha_Relativo', 'nome_arquivo', 'id_sujeito', 'grupo', 'fase', 'observacoes']
#
# Sucesso! Exibindo dados:
#                                    paciente grupo  Alpha_Relativo
# 0  record-[2025.07.30-10.10.28]_cleaned.fif    G2        0.667862
# 1  record-[2025.09.30-15.03.51]_cleaned.fif    G1        0.264644
# 2  record-[2025.10.21-11.46.36]_cleaned.fif    G3        0.189062
# 3  record-[2025.08.12-10.01.51]_cleaned.fif    G3        0.381529
# 4  record-[2025.10.20-09.47.01]_cleaned.fif    G2        0.586294
# 5  record-[2025.10.23-15.12.30]_cleaned.fif    G1        0.311575

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/python/3.12.1/bin/python

# %%
# EXTRAÇÃO DAS FEATURES

import os
import pandas as pd
import mne
import numpy as np
from scipy import signal, stats

# Definindo o caminho
proc_dir = "/workspaces/eeg-neuromodulation-mdd/data/processed"

# Agora, crie a lista arquivos_proc
arquivos_proc = [f for f in os.listdir(proc_dir) if f.endswith('.fif')]

# Verificação rápida
print(f"Arquivos encontrados para análise: {len(arquivos_proc)}")

# Definindo grupos de canais
frontais_esq = ['FP1', 'F3', 'F7']
frontais_dir = ['FP2', 'F4', 'F8']

resultados_profundos = []

for arq in arquivos_proc:
    raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
    psd = raw.compute_psd(method='welch', fmin=0.5, fmax=45)
    psd_data, freqs = psd.get_data(return_freqs=True)
    
    # Extrair potência
    def get_pow(ch_names, fmin, fmax):
        indices = [raw.ch_names.index(ch) for ch in ch_names]
        f_idx = (freqs >= fmin) & (freqs <= fmax)
        return np.mean(psd_data[indices, :][:, f_idx])

    # 1. AFA
    afa = np.log(get_pow(frontais_dir, 8, 13)) - np.log(get_pow(frontais_esq, 8, 13))
    
    # 2. TBR
    tbr = get_pow(raw.ch_names, 4, 8) / get_pow(raw.ch_names, 13, 30)
    
    # 3. Coerência Frontal (F3-F4) usando scipy
    f3_data = raw.get_data(picks=['F3'])[0]
    f4_data = raw.get_data(picks=['F4'])[0]
    freqs_coh, Cxy = signal.coherence(f3_data, f4_data, fs=512, nperseg=1024)
    # Media da coerencia na banda Beta (13-30Hz)
    mask_beta = (freqs_coh >= 13) & (freqs_coh <= 30)
    coerencia = np.mean(Cxy[mask_beta])
    
    # 4. Entropia de Shannon (mais estável para EEG)
    data = raw.get_data()
    # Normalização para calcular probabilidade
    ent = np.mean([stats.entropy(np.abs(data[i, :]) + 1e-12) for i in range(data.shape[0])])
    
    resultados_profundos.append({
        'paciente': arq,
        'AFA': afa, 'TBR': tbr, 'Coerencia': coerencia, 'Entropia': ent
    })

df_profundo = pd.DataFrame(resultados_profundos)
print("Análise Profunda Concluída:")
print(df_profundo.head())
# Out:
# Arquivos encontrados para análise: 6
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.07.30-10.10.28]_cleaned.fif...
# /tmp/ipykernel_75257/2896056237.py:25: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.07.30-10.10.28]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.09.30-15.03.51]_cleaned.fif...
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# /tmp/ipykernel_75257/2896056237.py:25: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.09.30-15.03.51]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.21-11.46.36]_cleaned.fif...
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# /tmp/ipykernel_75257/2896056237.py:25: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.21-11.46.36]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.08.12-10.01.51]_cleaned.fif...
# /tmp/ipykernel_75257/2896056237.py:25: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.08.12-10.01.51]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.20-09.47.01]_cleaned.fif...
# /tmp/ipykernel_75257/2896056237.py:25: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.20-09.47.01]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# Effective window size : 4.000 (s)
# Opening raw data file /workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.23-15.12.30]_cleaned.fif...
# /tmp/ipykernel_75257/2896056237.py:25: RuntimeWarning: This filename (/workspaces/eeg-neuromodulation-mdd/data/processed/record-[2025.10.23-15.12.30]_cleaned.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(os.path.join(proc_dir, arq), preload=True)
#     Range : 0 ... 307200 =      0.000 ...   600.000 secs
# Ready.
# Reading 0 ... 307200  =      0.000 ...   600.000 secs...
# Effective window size : 4.000 (s)
# Análise Profunda Concluída:
#                                    paciente       AFA       TBR  Coerencia  \
# 0  record-[2025.07.30-10.10.28]_cleaned.fif -0.018039  3.178502   0.246994
# 1  record-[2025.09.30-15.03.51]_cleaned.fif  0.227115  4.285466   0.105754
# 2  record-[2025.10.21-11.46.36]_cleaned.fif -0.037341  1.942285   0.060580
# 3  record-[2025.08.12-10.01.51]_cleaned.fif  0.053971  3.513132   0.781484
# 4  record-[2025.10.20-09.47.01]_cleaned.fif -0.096299  2.910728   0.036511
#
#     Entropia
# 0  12.310939
# 1  12.325171
# 2  12.342099
# 3  12.340440
# 4  12.289557
